# %%
# restart kernel and rerun for each subject (math/read/science/etc) to prevent kernel crash

# %%
import pyreadstat
import pandas as pd
import numpy as np

# %%
main_columns = ["CNT", "CNTSCHID", "CNTSTUID"]

# %%
math = [
    "CM033Q01TT",
    "CM033Q01F",
    "CM033Q01A",
    "CM033Q01V",
    "CM033Q01VS",
    "CM474Q01TT",
    "CM474Q01F",
    "CM474Q01A",
    "CM474Q01V",
    "CM474Q01VS",
    "CM155Q02TT",
    "CM155Q02F",
    "CM155Q02A",
    "CM155Q02V",
    "CM155Q02VS",
    "CM155Q01TT",
    "CM155Q01F",
    "CM155Q01A",
    "CM155Q01V",
    "CM155Q01VS",
    "CM155Q04TT",
    "CM155Q04F",
    "CM155Q04A",
    "CM155Q04V",
    "CM155Q04VS",
    "CM411Q01TT",
    "CM411Q01F",
    "CM411Q01A",
    "CM411Q01V",
    "CM411Q01VS",
    "CM411Q02TT",
    "CM411Q02F",
    "CM411Q02A",
    "CM411Q02V",
    "CM411Q02VS",
    "CM803Q01TT",
    "CM803Q01F",
    "CM803Q01A",
    "CM803Q01V",
    "CM803Q01VS",
    "CM442Q02TT",
    "CM442Q02F",
    "CM442Q02A",
    "CM442Q02V",
    "CM442Q02VS",
    "CM462Q01TT",
    "CM462Q01F",
    "CM462Q01A",
    "CM462Q01V",
    "CM462Q01VS",
    "CM034Q01TT",
    "CM034Q01F",
    "CM034Q01A",
    "CM034Q01V",
    "CM034Q01VS",
    "CM305Q01TT",
    "CM305Q01F",
    "CM305Q01A",
    "CM305Q01V",
    "CM305Q01VS",
    "CM496Q01TT",
    "CM496Q01F",
    "CM496Q01A",
    "CM496Q01V",
    "CM496Q01VS",
    "CM496Q02TT",
    "CM496Q02F",
    "CM496Q02A",
    "CM496Q02V",
    "CM496Q02VS",
    "CM423Q01TT",
    "CM423Q01F",
    "CM423Q01A",
    "CM423Q01V",
    "CM423Q01VS",
    "CM192Q01TT",
    "CM192Q01F",
    "CM192Q01A",
    "CM192Q01V",
    "CM192Q01VS",
    "CM603Q01TT",
    "CM603Q01F",
    "CM603Q01A",
    "CM603Q01V",
    "CM603Q01VS",
    "CM571Q01TT",
    "CM571Q01F",
    "CM571Q01A",
    "CM571Q01V",
    "CM571Q01VS",
    "CM564Q01TT",
    "CM564Q01F",
    "CM564Q01A",
    "CM564Q01V",
    "CM564Q01VS",
    "CM564Q02TT",
    "CM564Q02F",
    "CM564Q02A",
    "CM564Q02V",
    "CM564Q02VS",
    "CM447Q01TT",
    "CM447Q01F",
    "CM447Q01A",
    "CM447Q01V",
    "CM447Q01VS",
    "CM273Q01TT",
    "CM273Q01F",
    "CM273Q01A",
    "CM273Q01V",
    "CM273Q01VS",
    "CM408Q01TT",
    "CM408Q01F",
    "CM408Q01A",
    "CM408Q01V",
    "CM408Q01VS",
    "CM420Q01TT",
    "CM420Q01F",
    "CM420Q01A",
    "CM420Q01V",
    "CM420Q01VS",
    "CM446Q01TT",
    "CM446Q01F",
    "CM446Q01A",
    "CM446Q01V",
    "CM446Q01VS",
    "CR545Q07TT",
    "CR545Q07F",
    "CR545Q07A",
    "CR545Q07V",
    "CR545Q07VS",
    "CR220Q01TT",
    "CR220Q01F",
    "CR220Q01A",
    "CR220Q01V",
    "CR220Q01VS",
    "CR220Q02TT",
    "CR220Q02F",
    "CR220Q02A",
    "CR220Q02V",
    "CR220Q02VS",
    "CR220Q04TT",
    "CR220Q04F",
    "CR220Q04A",
    "CR220Q04V",
    "CR220Q04VS",
    "CR220Q05TT",
    "CR220Q05F",
    "CR220Q05A",
    "CR220Q05V",
    "CR220Q05VS",
    "CR220Q06TT",
    "CR220Q06F",
    "CR220Q06A",
    "CR220Q06V",
    "CR220Q06VS",
    "CR560Q10TT",
    "CR560Q10F",
    "CR560Q10A",
    "CR560Q10V",
    "CR560Q10VS",
    "CR560Q03TT",
    "CR560Q03F",
    "CR560Q03A",
    "CR560Q03V",
    "CR560Q03VS",
    "CR560Q06TT",
    "CR560Q06F",
    "CR560Q06A",
    "CR560Q06V",
    "CR560Q06VS",
    "CR560Q08TT",
    "CR560Q08F",
    "CR560Q08A",
    "CR560Q08V",
    "CR560Q08VS",
    "CR559Q01TT",
    "CR559Q01F",
    "CR559Q01A",
    "CR559Q01V",
    "CR559Q01VS",
    "CR559Q04TT",
    "CR559Q04F",
    "CR559Q04A",
    "CR559Q04V",
    "CR559Q04VS",
    "CR559Q03TT",
    "CR559Q03F",
    "CR559Q03A",
    "CR559Q03V",
    "CR559Q03VS",
    "CR559Q06TT",
    "CR559Q06F",
    "CR559Q06A",
    "CR559Q06V",
    "CR559Q06VS",
    "CR559Q08TT",
    "CR559Q08F",
    "CR559Q08A",
    "CR559Q08V",
    "CR559Q08VS",
    "CR404Q03TT",
    "CR404Q03F",
    "CR404Q03A",
    "CR404Q03V",
    "CR404Q03VS",
    "CR404Q06TT",
    "CR404Q06F",
    "CR404Q06A",
    "CR404Q06V",
    "CR404Q06VS",
    "CR404Q07TT",
    "CR404Q07F",
    "CR404Q07A",
    "CR404Q07V",
    "CR404Q07VS",
    "CR404Q10TT",
    "CR404Q10F",
    "CR404Q10A",
    "CR404Q10V",
    "CR404Q10VS",
    "CR565Q01TT",
    "CR565Q01F",
    "CR565Q01A",
    "CR565Q01V",
    "CR565Q01VS",
    "CR565Q02TT",
    "CR565Q02F",
    "CR565Q02A",
    "CR565Q02V",
    "CR565Q02VS",
    "CR565Q03TT",
    "CR565Q03F",
    "CR565Q03A",
    "CR565Q03V",
    "CR565Q03VS",
    "CR565Q05TT",
    "CR565Q05F",
    "CR565Q05A",
    "CR565Q05V",
    "CR565Q05VS",
    "CR565Q08TT",
    "CR565Q08F",
    "CR565Q08A",
    "CR565Q08V",
    "CR565Q08VS",
    "CR565Q09TT",
    "CR565Q09F",
    "CR565Q09A",
    "CR565Q09V",
    "CR565Q09VS",
    "CR547Q02TT",
    "CR547Q02F",
    "CR547Q02A",
    "CR547Q02V",
    "CR547Q02VS",
    "CR547Q09TT",
    "CR547Q09F",
    "CR547Q09A",
    "CR547Q09V",
    "CR547Q09VS",
    "CR547Q10TT",
    "CR547Q10F",
    "CR547Q10A",
    "CR547Q10V",
    "CR547Q10VS",
    "CR547Q03TT",
    "CR547Q03F",
    "CR547Q03A",
    "CR547Q03V",
    "CR547Q03VS",
    "CR547Q06TT",
    "CR547Q06F",
    "CR547Q06A",
    "CR547Q06V",
    "CR547Q06VS",
    "CR547Q07TT",
    "CR547Q07F",
    "CR547Q07A",
    "CR547Q07V",
    "CR547Q07VS",
    "CR558Q02TT",
    "CR558Q02F",
    "CR558Q02A",
    "CR558Q12TT",
    "CR558Q12F",
    "CR558Q12A",
    "CR558Q12V",
    "CR558Q12VS",
    "CR558Q02V",
    "CR558Q02VS",
    "CR558Q04TT",
    "CR558Q04F",
    "CR558Q04A",
    "CR558Q04V",
    "CR558Q04VS",
    "CR558Q06TT",
    "CR558Q06F",
    "CR558Q06A",
    "CR558Q06V",
    "CR558Q06VS",
    "CR558Q09TT",
    "CR558Q09F",
    "CR558Q09A",
    "CR558Q09V",
    "CR558Q09VS",
    "CR558Q10TT",
    "CR558Q10F",
    "CR558Q10A",
    "CR558Q10V",
    "CR558Q10VS",
    "CR455Q02TT",
    "CR455Q02F",
    "CR455Q02A",
    "CR455Q02V",
    "CR455Q02VS",
    "CR455Q03TT",
    "CR455Q03F",
    "CR455Q03A",
    "CR455Q03V",
    "CR455Q03VS",
    "CR455Q04TT",
    "CR455Q04F",
    "CR455Q04A",
    "CR455Q04V",
    "CR455Q04VS",
    "CR455Q05TT",
    "CR455Q05F",
    "CR455Q05A",
    "CR455Q05V",
    "CR455Q05VS",
    "CR540Q01TT",
    "CR540Q01F",
    "CR540Q01A",
    "CR540Q01V",
    "CR540Q01VS",
    "CR540Q03TT",
    "CR540Q03F",
    "CR540Q03A",
    "CR540Q03V",
    "CR540Q03VS",
    "CR540Q04TT",
    "CR540Q04F",
    "CR540Q04A",
    "CR540Q04V",
    "CR540Q04VS",
    "CR540Q05TT",
    "CR540Q05F",
    "CR540Q05A",
    "CR540Q05V",
    "CR540Q05VS",
    "CR540Q06TT",
    "CR540Q06F",
    "CR540Q06A",
    "CR540Q06V",
    "CR540Q06VS",
    "CR542Q01TT",
    "CR542Q01F",
    "CR542Q01A",
    "CR542Q01V",
    "CR542Q01VS",
    "CR542Q02TT",
    "CR542Q02F",
    "CR542Q02A",
    "CR542Q02V",
    "CR542Q02VS",
    "CR542Q05TT",
    "CR542Q05F",
    "CR542Q05A",
    "CR542Q05V",
    "CR542Q05VS",
    "CR542Q08TT",
    "CR542Q08F",
    "CR542Q08A",
    "CR542Q08V",
    "CR542Q08VS",
    "CR542Q09TT",
    "CR542Q09F",
    "CR542Q09A",
    "CR542Q09V",
    "CR542Q09VS",
    "CR561Q01TT",
    "CR561Q01F",
    "CR561Q01A",
    "CR561Q01V",
    "CR561Q01VS",
    "CR561Q03TT",
    "CR561Q03F",
    "CR561Q03A",
    "CR561Q03V",
    "CR561Q03VS",
    "CR561Q04TT",
    "CR561Q04F",
    "CR561Q04A",
    "CR561Q04V",
    "CR561Q04VS",
    "CR561Q06TT",
    "CR561Q06F",
    "CR561Q06A",
    "CR561Q06V",
    "CR561Q06VS",
    "CR561Q07TT",
    "CR561Q07F",
    "CR561Q07A",
    "CR561Q07V",
    "CR561Q07VS",
    "CR561Q08TT",
    "CR561Q08F",
    "CR561Q08A",
    "CR561Q08V",
    "CR561Q08VS",
    "CR564Q01TT",
    "CR564Q01F",
    "CR564Q01A",
    "CR564Q01V",
    "CR564Q01VS",
    "CR564Q02TT",
    "CR564Q02F",
    "CR564Q02A",
    "CR564Q02V",
    "CR564Q02VS",
    "CR564Q03TT",
    "CR564Q03F",
    "CR564Q03A",
    "CR564Q03V",
    "CR564Q03VS",
    "CR564Q04TT",
    "CR564Q04F",
    "CR564Q04A",
    "CR564Q04V",
    "CR564Q04VS",
    "CR564Q05TT",
    "CR564Q05F",
    "CR564Q05A",
    "CR564Q05V",
    "CR564Q05VS",
    "CR549Q04TT",
    "CR549Q04F",
    "CR549Q04A",
    "CR549Q04V",
    "CR549Q04VS",
    "CR549Q05TT",
    "CR549Q05F",
    "CR549Q05A",
    "CR549Q05V",
    "CR549Q05VS",
    "CR549Q06TT",
    "CR549Q06F",
    "CR549Q06A",
    "CR549Q06V",
    "CR549Q06VS",
    "CR549Q10TT",
    "CR549Q10F",
    "CR549Q10A",
    "CR549Q10V",
    "CR549Q10VS",
    "CR549Q12TT",
    "CR549Q12F",
    "CR549Q12A",
    "CR549Q12V",
    "CR549Q12VS",
    "CR549Q13TT",
    "CR549Q13F",
    "CR549Q13A",
    "CR549Q13V",
    "CR549Q13VS",
    "CR055Q05TT",
    "CR055Q05F",
    "CR055Q05A",
    "CR055Q05V",
    "CR055Q05VS",
    "CR055Q01TT",
    "CR055Q01F",
    "CR055Q01A",
    "CR055Q01V",
    "CR055Q01VS",
    "CR055Q02TT",
    "CR055Q02F",
    "CR055Q02A",
    "CR055Q02V",
    "CR055Q02VS",
    "CR055Q03TT",
    "CR055Q03F",
    "CR055Q03A",
    "CR055Q03V",
    "CR055Q03VS",
    "CR111Q01TT",
    "CR111Q01F",
    "CR111Q01A",
    "CR111Q01V",
    "CR111Q01VS",
    "CR111Q02BTT",
    "CR111Q02BF",
    "CR111Q02BA",
    "CR111Q02BV",
    "CR111Q02BVS",
    "CR111Q06TT",
    "CR111Q06F",
    "CR111Q06A",
    "CR111Q06V",
    "CR111Q06VS",
    "CR466Q02TT",
    "CR466Q02F",
    "CR466Q02A",
    "CR466Q02V",
    "CR466Q02VS",
    "CR466Q03TT",
    "CR466Q03F",
    "CR466Q03A",
    "CR466Q03V",
    "CR466Q03VS",
    "CR466Q06TT",
    "CR466Q06F",
    "CR466Q06A",
    "CR466Q06V",
    "CR466Q06VS",
    "CR550Q09TT",
    "CR550Q09F",
    "CR550Q09A",
    "CR550Q09V",
    "CR550Q09VS",
    "CR550Q10TT",
    "CR550Q10F",
    "CR550Q10A",
    "CR550Q10V",
    "CR550Q10VS",
    "CR550Q04TT",
    "CR550Q04F",
    "CR550Q04A",
    "CR541Q11F",
    "CR541Q11A",
    "CR541Q11V",
    "CR541Q11VS",
    "CR543Q01TT",
    "CR543Q01F",
    "CR543Q01A",
    "CR543Q01V",
    "CR543Q01VS",
    "CR543Q03TT",
    "CR543Q03F",
    "CR543Q03A",
    "CR543Q03V",
    "CR543Q03VS",
    "CR543Q04TT",
    "CR543Q04F",
    "CR543Q04A",
    "CR543Q04V",
    "CR543Q04VS",
    "CR543Q09TT",
    "CR543Q09F",
    "CR543Q09A",
    "CR543Q09V",
    "CR543Q09VS",
    "CR543Q10TT",
    "CR543Q10F",
    "CR543Q10A",
    "CR543Q10V",
    "CR543Q10VS",
    "CR543Q13TT",
    "CR543Q13F",
    "CR543Q13A",
    "CR543Q13V",
    "CR543Q13VS",
    "CR543Q15TT",
    "CR543Q15F",
    "CR543Q15A",
    "CR543Q15V",
    "CR543Q15VS",
    "CR544Q04TT",
    "CR544Q04F",
    "CR544Q04A",
    "CR544Q04V",
    "CR544Q04VS",
    "CR544Q06TT",
    "CR544Q06F",
    "CR544Q06A",
    "CR544Q06V",
    "CR544Q06VS",
    "CR544Q07TT",
    "CR544Q07F",
    "CR544Q07A",
    "CR544Q07V",
    "CR544Q07VS",
    "CR544Q10TT",
    "CR544Q10F",
    "CR544Q10A",
    "CR544Q10V",
    "CR544Q10VS",
    "CR544Q12TT",
    "CR544Q12F",
    "CR544Q12A",
    "CR544Q12V",
    "CR544Q12VS",
    "CR544Q13TT",
    "CR544Q13F",
    "CR544Q13A",
    "CR544Q13V",
    "CR544Q13VS",
    "CR544Q14TT",
    "CR544Q14F",
    "CR544Q14A",
    "CR544Q14V",
    "CR544Q14VS",
    "CR563Q09TT",
    "CR563Q09F",
    "CR563Q09A",
    "CR563Q09V",
    "CR563Q09VS",
    "CR563Q10TT",
    "CR563Q10F",
    "CR563Q10A",
    "CR563Q10V",
    "CR563Q10VS",
    "CR563Q07TT",
    "CR563Q07F",
    "CR563Q07A",
    "CR563Q07V",
    "CR563Q07VS",
    "CR563Q02TT",
    "CR563Q02F",
    "CR563Q02A",
    "CR563Q02V",
    "CR563Q02VS",
    "CR563Q03TT",
    "CR563Q03F",
    "CR563Q03A",
    "CR563Q03V",
    "CR563Q03VS",
    "CR563Q12TT",
    "CR563Q12F",
    "CR563Q12A",
    "CR563Q12V",
    "CR563Q12VS",
    "CR570Q01TT",
    "CR570Q01F",
    "CR570Q01A",
    "CR570Q01V",
    "CR570Q01VS",
    "CR570Q08TT",
    "CR570Q08F",
    "CR570Q08A",
    "CR570Q08V",
    "CR570Q08VS",
    "CR570Q10TT",
    "CR570Q10F",
    "CR570Q10A",
    "CR570Q10V",
    "CR570Q10VS",
    "CR570Q02TT",
    "CR570Q02F",
    "CR570Q02A",
    "CR570Q02V",
    "CR570Q02VS",
    "CR570Q04TT",
    "CR570Q04F",
    "CR570Q04A",
    "CR570Q04V",
    "CR570Q04VS",
    "CR570Q05TT",
    "CR570Q05F",
    "CR570Q05A",
    "CR570Q05V",
    "CR570Q05VS",
    "CR570Q06TT",
    "CR570Q06F",
    "CR570Q06A",
    "CR570Q06V",
    "CR570Q06VS",
    "CR566Q03TT",
    "CR566Q03F",
    "CR566Q03A",
    "CR566Q03V",
    "CR566Q03VS",
    "CR566Q04TT",
    "CR566Q04F",
    "CR566Q04A",
    "CR566Q04V",
    "CR566Q04VS",
    "CR566Q05TT",
    "CR566Q05F",
    "CR566Q05A",
    "CR566Q05V",
    "CR566Q05VS",
    "CR566Q14TT",
    "CR566Q14F",
    "CR566Q14A",
    "CR566Q14V",
    "CR566Q14VS",
    "CR566Q06TT",
    "CR566Q06F",
    "CR566Q06A",
    "CR566Q06V",
    "CR566Q06VS",
    "CR566Q09TT",
    "CR566Q09F",
    "CR566Q09A",
    "CR566Q09V",
    "CR566Q09VS",
    "CR566Q12TT",
    "CR566Q12F",
    "CR566Q12A",
    "CR566Q12V",
    "CR566Q12VS",
    "CR567Q03TT",
    "CR567Q03F",
    "CR567Q03A",
    "CR567Q03V",
    "CR567Q03VS",
    "CR567Q10TT",
    "CR567Q10F",
    "CR567Q10A",
    "CR567Q10V",
    "CR567Q10VS",
    "CR567Q11TT",
    "CR567Q11F",
    "CR567Q11A",
    "CR567Q11V",
    "CR567Q11VS",
    "CR567Q04TT",
    "CR567Q04F",
    "CR567Q04A",
    "CR567Q04V",
    "CR567Q04VS",
    "CR567Q06TT",
    "CR567Q06F",
    "CR567Q06A",
    "CR567Q06V",
    "CR567Q06VS",
    "CR567Q13TT",
    "CR567Q13F",
    "CR567Q13A",
    "CR567Q13V",
    "CR567Q13VS",
    "CR567Q08TT",
    "CR567Q08F",
    "CR567Q08A",
    "CR567Q08V",
    "CR567Q08VS",
    "CR219Q01TT",
    "CR219Q01F",
    "CR219Q01A",
    "CR219Q01V",
    "CR219Q01VS",
    "CR219Q02TT",
    "CR219Q02F",
    "CR219Q02A",
    "CR219Q02V",
    "CR219Q02VS",
    "CR460Q01TT",
    "CR460Q01F",
    "CR460Q01A",
    "CR460Q01V",
    "CR460Q01VS",
    "CR460Q05TT",
    "CR460Q05F",
    "CR460Q05A",
    "CR460Q05V",
    "CR460Q05VS",
    "CR460Q06TT",
    "CR460Q06F",
    "CR460Q06A",
    "CR460Q06V",
    "CR460Q06VS",
    "CR102Q04TT",
    "CR102Q04F",
    "CR102Q04A",
    "CR102Q04V",
    "CR102Q04VS",
    "CR102Q05TT",
    "CR102Q05F",
    "CR102Q05A",
    "CR102Q05V",
    "CR102Q05VS",
    "CR102Q07TT",
    "CR102Q07F",
    "CR102Q07A",
    "CR102Q07V",
    "CR102Q07VS",
    "CR432Q01TT",
    "CR432Q01F",
    "CR432Q01A",
    "CR432Q01V",
    "CR432Q01VS",
    "CR432Q05TT",
    "CR432Q05F",
    "CR432Q05A",
    "CR432Q05V",
    "CR432Q05VS",
    "CR432Q06TT",
    "CR432Q06F",
    "CR432Q06A",
    "CR432Q06V",
    "CR432Q06VS",
]

sci = [
    "CS408Q01TT",
    "CS408Q01F",
    "CS408Q01A",
    "CS408Q01V",
    "CS408Q01VS",
    "CS408Q03TT",
    "CS408Q03F",
    "CS408Q03A",
    "CS408Q03V",
    "CS408Q03VS",
    "CS408Q04TT",
    "CS408Q04F",
    "CS408Q04A",
    "CS408Q04V",
    "CS408Q04VS",
    "CS408Q05TT",
    "CS408Q05F",
    "CS408Q05A",
    "CS408Q05V",
    "CS408Q05VS",
    "CS413Q06TT",
    "CS413Q06F",
    "CS413Q06A",
    "CS413Q06V",
    "CS413Q06VS",
    "CS413Q04TT",
    "CS413Q04F",
    "CS413Q04A",
    "CS413Q04V",
    "CS413Q04VS",
    "CS413Q05TT",
    "CS413Q05F",
    "CS413Q05A",
    "CS413Q05V",
    "CS413Q05VS",
    "CS635Q01TT",
    "CS635Q01F",
    "CS635Q01A",
    "CS635Q01V",
    "CS635Q01VS",
    "CS635Q02TT",
    "CS635Q02F",
    "CS635Q02A",
    "CS635Q02V",
    "CS635Q02VS",
    "CS635Q03TT",
    "CS635Q03F",
    "CS635Q03A",
    "CS635Q03V",
    "CS635Q03VS",
    "CS635Q04TT",
    "CS635Q04F",
    "CS635Q04A",
    "CS635Q04N",
    "CS635Q04P",
    "CS635Q04Q",
    "CS635Q04V",
    "CS635Q04VS",
    "CS635Q05TT",
    "CS635Q05F",
    "CS635Q05A",
    "CS635Q05V",
    "CS635Q05VS",
    "CS604Q02TT",
    "CS604Q02F",
    "CS604Q02A",
    "CS604Q02V",
    "CS604Q02VS",
    "CS604Q04TT",
    "CS604Q04F",
    "CS604Q04A",
    "CS604Q04V",
    "CS604Q04VS",
    "CS625Q01TT",
    "CS625Q01F",
    "CS625Q01A",
    "CS625Q01V",
    "CS625Q01VS",
    "CS625Q02TT",
    "CS625Q02F",
    "CS625Q02A",
    "CS625Q02V",
    "CS625Q02VS",
    "CS625Q03TT",
    "CS625Q03F",
    "CS625Q03A",
    "CS625Q03V",
    "CS625Q03VS",
    "CS626Q01TT",
    "CS626Q01F",
    "CS626Q01A",
    "CS626Q01V",
    "CS626Q01VS",
    "CS626Q02TT",
    "CS626Q02F",
    "CS626Q02A",
    "CS626Q02V",
    "CS626Q02VS",
    "CS626Q03TT",
    "CS626Q03F",
    "CS626Q03A",
    "CS626Q03V",
    "CS626Q03VS",
    "CS425Q03TT",
    "CS425Q03F",
    "CS425Q03A",
    "CS425Q03V",
    "CS425Q03VS",
    "CS425Q05TT",
    "CS425Q05F",
    "CS425Q05A",
    "CS425Q05V",
    "CS425Q05VS",
    "CS425Q02TT",
    "CS425Q02F",
    "CS425Q02A",
    "CS425Q02V",
    "CS425Q02VS",
    "CS425Q04TT",
    "CS425Q04F",
    "CS425Q04A",
    "CS425Q04V",
    "CS425Q04VS",
    "CS438Q01TT",
    "CS438Q01F",
    "CS438Q01A",
    "CS438Q01V",
    "CS438Q01VS",
    "CS438Q02TT",
    "CS438Q02F",
    "CS438Q02A",
    "CS438Q02V",
    "CS438Q02VS",
    "CS438Q03TT",
    "CS438Q03F",
    "CS438Q03A",
    "CS438Q03V",
    "CS438Q03VS",
    "CS608Q01TT",
    "CS608Q01F",
    "CS608Q01A",
    "CS608Q01V",
    "CS608Q01VS",
    "CS608Q02TT",
    "CS608Q02F",
    "CS608Q02A",
    "CS608Q02V",
    "CS608Q02VS",
    "CS608Q03TT",
    "CS608Q03F",
    "CS608Q03A",
    "CS608Q03V",
    "CS608Q03VS",
    "CS608Q04TT",
    "CS608Q04F",
    "CS608Q04A",
    "CS608Q04V",
    "CS608Q04VS",
    "CS643Q03TT",
    "CS643Q03F",
    "CS643Q03A",
    "CS643Q03V",
    "CS643Q03VS",
    "CS643Q01TT",
    "CS643Q01F",
    "CS643Q01A",
    "CS643Q01V",
    "CS643Q01VS",
    "CS643Q02TT",
    "CS643Q02F",
    "CS643Q02A",
    "CS643Q02V",
    "CS643Q02VS",
    "CS643Q04TT",
    "CS643Q04F",
    "CS643Q04A",
    "CS643Q04N",
    "CS643Q04P",
    "CS643Q04Q",
    "CS643Q04V",
    "CS643Q04VS",
    "CS643Q05TT",
    "CS643Q05F",
    "CS643Q05A",
    "CS643Q05V",
    "CS643Q05VS",
    "CS610Q01TT",
    "CS610Q01F",
    "CS610Q01A",
    "CS610Q01V",
    "CS610Q01VS",
    "CS610Q02TT",
    "CS610Q02F",
    "CS610Q02A",
    "CS610Q02V",
    "CS610Q02VS",
    "CS466Q01TT",
    "CS466Q01F",
    "CS466Q01A",
    "CS466Q01V",
    "CS466Q01VS",
    "CS466Q07TT",
    "CS466Q07F",
    "CS466Q07A",
    "CS466Q07V",
    "CS466Q07VS",
    "CS256Q01TT",
    "CS256Q01F",
    "CS256Q01A",
    "CS256Q01V",
    "CS256Q01VS",
    "CS326Q01TT",
    "CS326Q01F",
    "CS326Q01A",
    "CS326Q01V",
    "CS326Q01VS",
    "CS326Q02TT",
    "CS326Q02F",
    "CS326Q02A",
    "CS326Q02V",
    "CS326Q02VS",
    "CS326Q03TT",
    "CS326Q03F",
    "CS326Q03A",
    "CS326Q03V",
    "CS326Q03VS",
    "CS326Q04TT",
    "CS326Q04F",
    "CS326Q04A",
    "CS326Q04V",
    "CS326Q04VS",
    "CS602Q01TT",
    "CS602Q01F",
    "CS602Q01A",
    "CS602Q01V",
    "CS602Q01VS",
    "CS602Q02TT",
    "CS602Q02F",
    "CS602Q02A",
    "CS602Q02V",
    "CS602Q02VS",
    "CS602Q03TT",
    "CS602Q03F",
    "CS602Q03A",
    "CS602Q03V",
    "CS602Q03VS",
    "CS602Q04TT",
    "CS602Q04F",
    "CS602Q04A",
    "CS602Q04V",
    "CS602Q04VS",
    "CS603Q01TT",
    "CS603Q01F",
    "CS603Q01A",
    "CS603Q01V",
    "CS603Q01VS",
    "CS603Q02TT",
    "CS603Q02F",
    "CS603Q02A",
    "CS603Q02V",
    "CS603Q02VS",
    "CS603Q03TT",
    "CS603Q03F",
    "CS603Q03A",
    "CS603Q03V",
    "CS603Q03VS",
    "CS603Q04TT",
    "CS603Q04F",
    "CS603Q04A",
    "CS603Q04V",
    "CS603Q04VS",
    "CS603Q05TT",
    "CS603Q05F",
    "CS603Q05A",
    "CS603Q05V",
    "CS603Q05VS",
    "CS657Q01TT",
    "CS657Q01F",
    "CS657Q01A",
    "CS657Q01V",
    "CS657Q01VS",
    "CS657Q02TT",
    "CS657Q02F",
    "CS657Q02A",
    "CS657Q02V",
    "CS657Q02VS",
    "CS657Q03TT",
    "CS657Q03F",
    "CS657Q03A",
    "CS657Q03V",
    "CS657Q03VS",
    "CS657Q04TT",
    "CS657Q04F",
    "CS657Q04A",
    "CS657Q04V",
    "CS657Q04VS",
    "CS527Q01TT",
    "CS527Q01F",
    "CS527Q01A",
    "CS527Q01V",
    "CS527Q01VS",
    "CS527Q03TT",
    "CS527Q03F",
    "CS527Q03A",
    "CS527Q03V",
    "CS527Q03VS",
    "CS527Q04TT",
    "CS527Q04F",
    "CS527Q04A",
    "CS527Q04V",
    "CS527Q04VS",
    "CS428Q01TT",
    "CS428Q01F",
    "CS428Q01A",
    "CS428Q01V",
    "CS428Q01VS",
    "CS428Q03TT",
    "CS428Q03F",
    "CS428Q03A",
    "CS428Q03V",
    "CS428Q03VS",
    "CS428Q05TT",
    "CS428Q05F",
    "CS428Q05A",
    "CS428Q05V",
    "CS428Q05VS",
    "CS634Q01TT",
    "CS634Q01F",
    "CS634Q01A",
    "CS634Q01V",
    "CS634Q01VS",
    "CS634Q02TT",
    "CS634Q02F",
    "CS634Q02A",
    "CS634Q02V",
    "CS634Q02VS",
    "CS634Q03TT",
    "CS634Q03F",
    "CS634Q03A",
    "CS634Q03V",
    "CS634Q03VS",
    "CS634Q05TT",
    "CS634Q05F",
    "CS634Q05A",
    "CS634Q05V",
    "CS634Q05VS",
    "CS634Q04TT",
    "CS634Q04F",
    "CS634Q04A",
    "CS634Q04V",
    "CS634Q04VS",
    "CS629Q01TT",
    "CS629Q01F",
    "CS629Q01A",
    "CS629Q01V",
    "CS629Q01VS",
    "CS629Q02TT",
    "CS629Q02F",
    "CS629Q02A",
    "CS629Q02V",
    "CS629Q02VS",
    "CS629Q03TT",
    "CS629Q03F",
    "CS629Q03A",
    "CS629Q03V",
    "CS629Q03VS",
    "CS629Q04TT",
    "CS629Q04F",
    "CS629Q04A",
    "CS629Q04V",
    "CS629Q04VS",
    "CS648Q01TT",
    "CS648Q01F",
    "CS648Q01A",
    "CS648Q01V",
    "CS648Q01VS",
    "CS648Q02TT",
    "CS648Q02F",
    "CS648Q02A",
    "CS648Q02V",
    "CS648Q02VS",
    "CS648Q03TT",
    "CS648Q03F",
    "CS648Q03A",
    "CS648Q03V",
    "CS648Q03VS",
    "CS498Q02TT",
    "CS498Q02F",
    "CS498Q02A",
    "CS498Q02V",
    "CS498Q02VS",
    "CS498Q03TT",
    "CS498Q03F",
    "CS498Q03A",
    "CS498Q03V",
    "CS498Q03VS",
    "CS498Q04TT",
    "CS498Q04F",
    "CS498Q04A",
    "CS498Q04V",
    "CS498Q04VS",
    "CS514Q02TT",
    "CS514Q02F",
    "CS514Q02A",
    "CS514Q02V",
    "CS514Q02VS",
    "CS514Q03TT",
    "CS514Q03F",
    "CS514Q03A",
    "CS514Q03V",
    "CS514Q03VS",
    "CS514Q04TT",
    "CS514Q04F",
    "CS514Q04A",
    "CS514Q04V",
    "CS514Q04VS",
    "CS605Q01TT",
    "CS605Q01F",
    "CS605Q01A",
    "CS605Q01V",
    "CS605Q01VS",
    "CS605Q02TT",
    "CS605Q02F",
    "CS605Q02A",
    "CS605Q02V",
    "CS605Q02VS",
    "CS605Q03TT",
    "CS605Q03F",
    "CS605Q03A",
    "CS605Q03V",
    "CS605Q03VS",
    "CS605Q04TT",
    "CS605Q04F",
    "CS605Q04A",
    "CS605Q04V",
    "CS605Q04VS",
    "CS646Q01TT",
    "CS646Q01F",
    "CS646Q01A",
    "CS646Q01N",
    "CS646Q01P",
    "CS646Q01Q",
    "CS646Q01V",
    "CS646Q01VS",
    "CS646Q02TT",
    "CS646Q02F",
    "CS646Q02A",
    "CS646Q02N",
    "CS646Q02P",
    "CS646Q02Q",
    "CS646Q02V",
    "CS646Q02VS",
    "CS646Q03TT",
    "CS646Q03F",
    "CS646Q03A",
    "CS646Q03N",
    "CS646Q03P",
    "CS646Q03Q",
    "CS646Q03V",
    "CS646Q03VS",
    "CS646Q04TT",
    "CS646Q04F",
    "CS646Q04A",
    "CS646Q04N",
    "CS646Q04P",
    "CS646Q04Q",
    "CS646Q04V",
    "CS646Q04VS",
    "CS646Q05TT",
    "CS646Q05F",
    "CS646Q05A",
    "CS646Q05V",
    "CS646Q05VS",
    "CS620Q01TT",
    "CS620Q01F",
    "CS620Q01A",
    "CS620Q01V",
    "CS620Q01VS",
    "CS620Q02TT",
    "CS620Q02F",
    "CS620Q02A",
    "CS620Q02V",
    "CS620Q02VS",
    "CS645Q01TT",
    "CS645Q01F",
    "CS645Q01A",
    "CS645Q01V",
    "CS645Q01VS",
    "CS645Q03TT",
    "CS645Q03F",
    "CS645Q03A",
    "CS645Q03V",
    "CS645Q03VS",
    "CS645Q04TT",
    "CS645Q04F",
    "CS645Q04A",
    "CS645Q04V",
    "CS645Q04VS",
    "CS478Q01TT",
    "CS478Q01F",
    "CS478Q01A",
    "CS478Q01V",
    "CS478Q01VS",
    "CS478Q02TT",
    "CS478Q02F",
    "CS478Q02A",
    "CS478Q02V",
    "CS478Q02VS",
    "CS478Q03TT",
    "CS478Q03F",
    "CS478Q03A",
    "CS478Q03V",
    "CS478Q03VS",
    "CS415Q07TT",
    "CS415Q07F",
    "CS415Q07A",
    "CS415Q07V",
    "CS415Q07VS",
    "CS415Q02TT",
    "CS415Q02F",
    "CS415Q02A",
    "CS415Q02V",
    "CS415Q02VS",
    "CS415Q08TT",
    "CS415Q08F",
    "CS415Q08A",
    "CS415Q08V",
    "CS415Q08VS",
    "CS627Q01TT",
    "CS627Q01F",
    "CS627Q01A",
    "CS627Q01V",
    "CS627Q01VS",
    "CS627Q03TT",
    "CS627Q03F",
    "CS627Q03A",
    "CS627Q03V",
    "CS627Q03VS",
    "CS627Q04TT",
    "CS627Q04F",
    "CS627Q04A",
    "CS627Q04V",
    "CS627Q04VS",
    "CS607Q01TT",
    "CS607Q01F",
    "CS607Q01A",
    "CS607Q01V",
    "CS607Q01VS",
    "CS607Q02TT",
    "CS607Q02F",
    "CS607Q02A",
    "CS607Q02V",
    "CS607Q02VS",
    "CS607Q03TT",
    "CS607Q03F",
    "CS607Q03A",
    "CS607Q03V",
    "CS607Q03VS",
    "CS638Q01TT",
    "CS638Q01F",
    "CS638Q01A",
    "CS638Q01V",
    "CS638Q01VS",
    "CS638Q02TT",
    "CS638Q02F",
    "CS638Q02A",
    "CS638Q02V",
    "CS638Q02VS",
    "CS638Q04TT",
    "CS638Q04F",
    "CS638Q04A",
    "CS638Q04V",
    "CS638Q04VS",
    "CS615Q07TT",
    "CS615Q07F",
    "CS615Q07A",
    "CS615Q07N",
    "CS615Q07P",
    "CS615Q07Q",
    "CS615Q07V",
    "CS615Q07VS",
    "CS615Q01TT",
    "CS615Q01F",
    "CS615Q01A",
    "CS615Q01N",
    "CS615Q01P",
    "CS615Q01Q",
    "CS615Q01V",
    "CS615Q01VS",
    "CS615Q02TT",
    "CS615Q02F",
    "CS615Q02A",
    "CS615Q02N",
    "CS615Q02P",
    "CS615Q02Q",
    "CS615Q02V",
    "CS615Q02VS",
    "CS615Q05TT",
    "CS615Q05F",
    "CS615Q05A",
    "CS615Q05V",
    "CS615Q05VS",
]

# %%
math_resp = ['CM033Q01S',
'CM474Q01S',
'DM155Q02C',
'CM155Q01S',
'CM155Q04S',
'CM411Q01S',
'CM411Q02S',
'CM803Q01S',
'CM442Q02S',
'DM462Q01C',
'CM034Q01S',
'CM305Q01S',
'CM496Q01S',
'CM496Q02S',
'CM423Q01S',
'CM192Q01S',
'CM603Q01S',
'CM571Q01S',
'CM564Q01S',
'CM564Q02S',
'CM447Q01S',
'CM273Q01S',
'CM408Q01S',
'CM420Q01S',
'CM446Q01S',
'DM446Q02C',
'CM559Q01S',
'DM828Q02C',
'CM828Q03S',
'CM464Q01S',
'CM800Q01S',
'CM982Q01S',
'CM982Q02S',
'CM982Q03S',
'CM982Q04S',
'CM992Q01S',
'CM992Q02S',
'DM992Q03C',
'CM915Q01S',
'CM915Q02S',
'CM906Q01S',
'DM906Q02C',
'DM00KQ02C',
'CM909Q01S',
'CM909Q02S',
'CM909Q03S',
'CM949Q01S',
'CM949Q02S',
'DM949Q03C',
'CM00GQ01S',
'DM955Q01C',
'DM955Q02C',
'CM955Q03S',
'DM998Q02C',
'CM905Q01S',
'DM905Q02C',
'CM919Q01S',
'CM919Q02S',
'CM954Q01S',
'DM954Q02C',
'CM954Q04S',
'CM943Q01S',
'CM943Q02S',
'DM953Q02C',
'CM953Q03S',
'DM953Q04C',
'CM948Q01S',
'CM948Q02S',
'CM948Q03S',
'CM936Q01S',
'DM936Q02C',
'CM939Q02S',
'CM967Q01S',
'CM967Q03S',
'CMA105Q01S',
'CMA105Q02S',
'CMA105Q03S',
'CMA105Q04S',
'CMA105Q05S',
'CMA110Q01S',
'CMA110Q02S',
'DMA110Q03C',
'CMA149Q02S',
'DMA149Q03C',
'CMA121Q01S',
'CMA121Q02S',
'CMA121Q03S',
'CMA111Q01S',
'CMA111Q02S',
'DMA111Q03C',
'CMA135Q01S',
'CMA135Q02S',
'CMA135Q03S',
'CMA135Q04S']

read_resp = ['CR590Q04S',
'CR590Q27S',
'CR590Q03S',
'CR590Q59S',
'CR590Q33S',
'CR590Q20S',
'CR590Q24S',
'CR590Q43S',
'CR590Q52S',
'CR590Q35S',
'CR590Q61S',
'CR590Q02S',
'CR590Q18S',
'CR590Q10S',
'CR590Q37S',
'CR590Q42S',
'CR590Q45S',
'CR590Q25S',
'CR590Q13S',
'CR590Q57S',
'CR590Q41S',
'CR590Q60S',
'CR590Q05S',
'CR590Q01S',
'CR590Q22S',
'CR590Q47S',
'CR590Q34S',
'CR590Q23S',
'CR590Q38S',
'CR590Q55S',
'CR590Q14S',
'CR590Q65S',
'CR590Q26S',
'CR590Q48S',
'CR590Q44S',
'CR590Q19S',
'CR590Q15S',
'CR590Q30S',
'CR590Q28S',
'CR590Q09S',
'CR590Q56S',
'CR590Q16S',
'CR590Q58S',
'CR590Q46S',
'CR590Q06S',
'CR590Q50S',
'CR590Q07S',
'CR590Q31S',
'CR590Q32S',
'CR590Q51S',
'CR590Q39S',
'CR590Q54S',
'CR590Q53S',
'CR590Q64S',
'CR590Q08S',
'CR590Q36S',
'CR590Q21S',
'CR590Q49S',
'CR590Q40S',
'CR590Q11S',
'CR590Q29S',
'CR590Q63S',
'CR590Q17S',
'CR590Q62S',
'CR590Q66S',
'CR545Q02S',
'CR545Q03S',
'CR545Q03SA',
'CR545Q03SB',
'CR545Q03SC',
'CR545Q03SD',
'DR545Q04C',
'CR545Q06S',
'CR545Q07S',
'CR220Q01S',
'CR220Q02S',
'CR220Q04S',
'CR220Q05S',
'CR220Q06S',
'CR560Q10S',
'CR560Q03S',
'CR560Q06S',
'CR560Q08S',
'CR559Q01S',
'CR559Q04S',
'CR559Q03S',
'CR559Q06S',
'DR559Q08C',
'CR404Q03S',
'CR404Q06S',
'CR404Q07S',
'DR404Q10AC',
'DR404Q10BC',
'CR565Q01S',
'DR565Q02C',
'CR565Q03S',
'DR565Q05C',
'CR565Q08S',
'CR565Q09S',
'CR547Q02S',
'CR547Q07SF',
'DR547Q09C',
'CR547Q10S',
'CR547Q03S',
'CR547Q06S',
'CR547Q07S',
'CR547Q07SA',
'CR547Q07SB',
'CR547Q07SC',
'CR547Q07SD',
'CR547Q07SE',
'CR558Q02S',
'CR558Q10SB',
'CR558Q10SC',
'CR558Q10SD',
'DR558Q12C',
'CR558Q02SA',
'CR558Q02SB',
'CR558Q02SC',
'DR558Q04C',
'CR558Q06S',
'CR558Q09S',
'CR558Q10S',
'CR558Q10SA',
'DR455Q02C',
'DR455Q03C',
'CR455Q04S',
'CR455Q05S',
'CR540Q01S',
'CR540Q03S',
'DR540Q04C',
'CR540Q05S',
'CR540Q06S',
'CR542Q01S',
'DR542Q02C',
'CR542Q05S',
'CR542Q08S',
'CR542Q09S',
'CR561Q01S',
'CR561Q03S',
'CR561Q04S',
'CR561Q04SA',
'CR561Q04SB',
'CR561Q04SC',
'CR561Q06S',
'DR561Q07C',
'CR561Q08S',
'CR564Q01S',
'CR564Q02S',
'CR564Q03S',
'CR564Q04S',
'DR564Q05C',
'CR549Q04S',
'CR549Q13SB',
'CR549Q13SC',
'CR549Q13SD',
'DR549Q05C',
'CR549Q06S',
'CR549Q10S',
'CR549Q12S',
'CR549Q12SA',
'CR549Q12SB',
'CR549Q12SD',
'CR549Q13S',
'DR055Q05C',
'CR055Q01S',
'DR055Q02C',
'DR055Q03C',
'CR111Q01S',
'DR111Q02BC',
'DR111Q06C',
'DR466Q02C',
'CR466Q03S',
'CR466Q06S',
'DR550Q09C',
'DR550Q10C',
'CR550Q04S',
'CR550Q05S',
'CR550Q06S',
'DR550Q07C',
'CR562Q02S',
'DR562Q03C',
'CR562Q05S',
'DR562Q06C',
'CR562Q07S',
'CR569Q01S',
'CR569Q02S',
'CR569Q03S',
'CR569Q04S',
'DR569Q06C',
'CR553Q02S',
'CR553Q01S',
'DR553Q04C',
'DR553Q06C',
'CR553Q05S',
'CR553Q07S',
'CR456Q01S',
'DR456Q02C',
'DR456Q06C',
'CR446Q03S',
'DR446Q06C',
'CR453Q01S',
'DR453Q04C',
'CR453Q05S',
'DR453Q06C',
'CR552Q01S',
'CR552Q09S',
'CR552Q06S',
'DR552Q03C',
'DR552Q11C',
'DR552Q04C',
'DR552Q08C',
'CR556Q01S',
'CR556Q12SC',
'CR556Q12SD',
'CR556Q03S',
'CR556Q04S',
'CR556Q05S',
'DR556Q09C',
'CR556Q10S',
'CR556Q12S',
'CR556Q12SA',
'CR556Q12SB',
'CR568Q14S',
'CR568Q05S',
'DR568Q06C',
'CR568Q15S',
'CR568Q08S',
'CR568Q10S',
'DR568Q13C',
'CR541Q01S',
'CR541Q03S',
'DR541Q04C',
'CR541Q05S',
'DR541Q09C',
'CR541Q10S',
'DR541Q11C',
'CR543Q01S',
'CR543Q03S',
'CR543Q04S',
'CR543Q09S',
'CR543Q10S',
'CR543Q13S',
'DR543Q15C',
'CR544Q04S',
'CR544Q14SC',
'CR544Q14SD',
'CR544Q14SE',
'CR544Q06S',
'DR544Q07C',
'CR544Q10S',
'CR544Q12S',
'DR544Q13C',
'CR544Q14S',
'CR544Q14SA',
'CR544Q14SB',
'DR563Q09C',
'CR563Q10S',
'CR563Q07S',
'CR563Q02S',
'CR563Q03S',
'DR563Q12C',
'DR563Q13C',
'DR563Q14C',
'CR570Q01S',
'CR570Q08S',
'DR570Q10C',
'CR570Q02S',
'CR570Q04S',
'CR570Q04SA',
'CR570Q04SB',
'CR570Q04SC',
'CR570Q04SD',
'CR570Q05S',
'CR570Q06S',
'DR566Q03C',
'CR566Q04S',
'CR566Q05S',
'CR566Q14S',
'CR566Q06S',
'CR566Q09S',
'DR566Q12C',
'DR567Q03C',
'CR567Q08SE',
'CR567Q10S',
'CR567Q11S',
'CR567Q11SA',
'CR567Q11SC',
'CR567Q11SD',
'CR567Q11SF',
'CR567Q04S',
'CR567Q06S',
'CR567Q13S',
'CR567Q08S',
'CR567Q08SA',
'CR567Q08SB',
'CR567Q08SC',
'CR567Q08SD',
'DR219Q01AC',
'DR219Q01BC',
'DR219Q01CC',
'DR219Q01DC',
'DR219Q01C',
'DR219Q01EC',
'DR219Q02C',
'DR460Q01C',
'CR460Q05S',
'CR460Q06S',
'DR102Q04C',
'DR102Q05C',
'CR102Q07S',
'DR432Q01C',
'DR432Q05C',
'CR432Q06S']

sci_resp = ['CS408Q01S',
'DS408Q03C',
'CS408Q04S',
'CS408Q05S',
'CS413Q06S',
'CS413Q04S',
'CS413Q05S',
'CS635Q01S',
'CS635Q02S',
'DS635Q03C',
'CS635Q04S',
'DS635Q05C',
'CS604Q02S',
'DS604Q04C',
'DS625Q01C',
'CS625Q02S',
'CS625Q03S',
'CS626Q01S',
'CS626Q02S',
'CS626Q03S',
'DS425Q03C',
'CS425Q05S',
'CS425Q02S',
'DS425Q04C',
'CS438Q01S',
'CS438Q02S',
'DS438Q03C',
'CS608Q01S',
'CS608Q02S',
'CS608Q03S',
'DS608Q04C',
'DS643Q03C',
'CS643Q01S',
'CS643Q02S',
'CS643Q04S',
'DS643Q05C',
'DS610Q01C',
'CS610Q02S',
'CS466Q01S',
'CS466Q07S',
'CS256Q01S',
'DS326Q01C',
'DS326Q02C',
'CS326Q03S',
'CS326Q04S',
'CS602Q01S',
'CS602Q02S',
'DS602Q03C',
'CS602Q04S',
'CS603Q01S',
'DS603Q02C',
'CS603Q03S',
'CS603Q04S',
'CS603Q05S',
'CS657Q01S',
'CS657Q02S',
'CS657Q03S',
'DS657Q04C',
'CS527Q01S',
'CS527Q03S',
'CS527Q04S',
'CS428Q01S',
'CS428Q03S',
'DS428Q05C',
'CS634Q01S',
'CS634Q02S',
'DS634Q03C',
'DS634Q05C',
'CS634Q04S',
'DS629Q01C',
'CS629Q02S',
'DS629Q03C',
'CS629Q04S',
'DS648Q01C',
'CS648Q02S',
'CS648Q03S',
'CS498Q02S',
'CS498Q03S',
'DS498Q04C',
'DS514Q02C',
'DS514Q03C',
'DS514Q04C',
'CS605Q01S',
'CS605Q02S',
'CS605Q03S',
'DS605Q04C',
'CS646Q01S',
'CS646Q02S',
'CS646Q03S',
'DS646Q04C',
'DS646Q05C',
'CS620Q01S',
'CS620Q02S',
'CS645Q01S',
'CS645Q03S',
'DS645Q04C',
'CS478Q01S',
'CS478Q02S',
'CS478Q03S',
'CS415Q07S',
'CS415Q02S',
'CS415Q08S',
'CS627Q01S',
'CS627Q03S',
'CS627Q04S',
'CS607Q01S',
'CS607Q02S',
'DS607Q03C',
'CS638Q01S',
'CS638Q02S',
'CS638Q04S',
'CS615Q07S',
'CS615Q01S',
'CS615Q02S',
'CS615Q05S']

# %%
math_proc = main_columns + math
read_proc = main_columns + read
sci_proc = main_columns + sci

math_ir = main_columns + math_resp
read_ir = main_columns + read_resp
sci_ir = main_columns + sci_resp

# %%
def process_and_pivot(df, id_vars):
    df_long = df.melt(
        id_vars=id_vars,
        var_name="item",
        value_name="resp"
    )
    
    df_long = df_long.rename(
        columns={"CNTSTUID": "id"}
    )
    
    df_long["item"] = df_long["item"].str[:-1]

    df_long["item_join"] = "C" + df_long["item"].str[1:]
    
    df_long = df_long.dropna(subset=["resp"])
    
    return df_long

# %%
df_math_resp, meta = pyreadstat.read_sav("CY08MSP_STU_COG.sav", usecols=math_ir)
# df_read_resp, meta = pyreadstat.read_sav("CY08MSP_STU_COG.sav", usecols=read_ir)
# df_sci_resp, meta = pyreadstat.read_sav("CY08MSP_STU_COG.sav", usecols=sci_ir)

# %%
df_math_ir = process_and_pivot(df_math_resp, main_columns)
# df_read_ir = process_and_pivot(df_read_resp, main_columns)
# df_sci_ir = process_and_pivot(df_sci_resp, main_columns)

# %%
# df_math_ir
# df_read_ir
# df_sci_ir

# %%
def process_and_pivot_p(df, id_vars, chunk_size=1000):
    
    processed_chunks = []
    
    total_chunks = (len(df) + chunk_size - 1) // chunk_size
    
    for chunk_num, start_idx in enumerate(range(0, len(df), chunk_size), 1):
        
        print(f"Processing chunk {chunk_num} of {total_chunks} ({(chunk_num/total_chunks*100):.1f}%)")
        
        chunk = df.iloc[start_idx:start_idx + chunk_size].copy()
        
        chunk_long = chunk.melt(
            id_vars=id_vars,
            var_name="event_id", 
            value_name="event_value"
        )
        
        chunk_long = chunk_long.rename(
            columns={"CNTSTUID": "id"}
        )
        
        conditions = [
            chunk_long["event_id"].str.endswith("TT"),
            chunk_long["event_id"].str.endswith("F"),
            chunk_long["event_id"].str.endswith("A"),
            chunk_long["event_id"].str.endswith("V"),
            chunk_long["event_id"].str.endswith("VS")
        ]
        
        choices = [
            "rt",
            "time_to_first_action",
            "num_actions",
            "num_visits",
            "num_short_visits"
        ]
        
        chunk_long["item"] = np.where(
            chunk_long["event_id"].str.endswith(("TT", "VS")), 
            chunk_long["event_id"].str[:-2], 
            chunk_long["event_id"].str[:-1]
        )
        
        chunk_long["event_type"] = np.select(conditions, choices, default="unknown")
        chunk_long = chunk_long.dropna(subset=["event_value"])
        
        processed_chunks.append(chunk_long)
        
        del chunk_long
    
    print("Combining chunks...")
    df_long = pd.concat(processed_chunks, ignore_index=True)
    
    return df_long

# %%
df_math_proc, meta = pyreadstat.read_sav("CY08MSP_STU_COG.sav", usecols=math_proc)
# df_read_proc, meta = pyreadstat.read_sav("CY08MSP_STU_COG.sav", usecols=read_proc)
# df_sci_proc, meta = pyreadstat.read_sav("CY08MSP_STU_COG.sav", usecols=sci_proc)

# %%
df_math_p = process_and_pivot_p(df_math_proc, main_columns)
# df_read_p = process_and_pivot_p(df_read_proc, main_columns)
# df_sci_p = process_and_pivot_p(df_sci_proc, main_columns)
# Out:
# Processing chunk 1 of 614 (0.2%)
# Processing chunk 2 of 614 (0.3%)
# Processing chunk 3 of 614 (0.5%)
# Processing chunk 4 of 614 (0.7%)
# Processing chunk 5 of 614 (0.8%)
# Processing chunk 6 of 614 (1.0%)
# Processing chunk 7 of 614 (1.1%)
# Processing chunk 8 of 614 (1.3%)
# Processing chunk 9 of 614 (1.5%)
# Processing chunk 10 of 614 (1.6%)
# Processing chunk 11 of 614 (1.8%)
# Processing chunk 12 of 614 (2.0%)
# Processing chunk 13 of 614 (2.1%)
# Processing chunk 14 of 614 (2.3%)
# Processing chunk 15 of 614 (2.4%)
# Processing chunk 16 of 614 (2.6%)
# Processing chunk 17 of 614 (2.8%)
# Processing chunk 18 of 614 (2.9%)
# Processing chunk 19 of 614 (3.1%)
# Processing chunk 20 of 614 (3.3%)
# Processing chunk 21 of 614 (3.4%)
# Processing chunk 22 of 614 (3.6%)
# Processing chunk 23 of 614 (3.7%)
# Processing chunk 24 of 614 (3.9%)
# Processing chunk 25 of 614 (4.1%)
# Processing chunk 26 of 614 (4.2%)
# Processing chunk 27 of 614 (4.4%)
# Processing chunk 28 of 614 (4.6%)
# ...

# %%
# df_math_p
# df_read_p
# df_sci_p

# %%
df_math_p = df_math_p[['CNT', 'CNTSCHID', 'id', 'item', 'event_type', 'event_value']]
# df_read_p = df_read_p[['CNT', 'CNTSCHID', 'id', 'item', 'event_type', 'event_value']]
# df_sci_p = df_sci_p[['CNT', 'CNTSCHID', 'id', 'item', 'event_type', 'event_value']]

# %%
df_math_p = df_math_p[(df_math_p['event_type'] != 'unknown')]
# df_read_p = df_read_p[(df_read_p['event_type'] != 'unknown')]
# df_sci_p = df_sci_p[(df_sci_p['event_type'] != 'unknown')]

# %%
# df_math_p
# df_read_p
# df_sci_p

# %%
def process_and_pivot_by_cnt(df):
    
    unique_cnts = df['CNT'].unique()
    print(f"Processing {len(unique_cnts)} unique countries...")
    
    pivoted_chunks = []
    
    for i, cnt in enumerate(unique_cnts, 1):
        print(f"Processing country {i} of {len(unique_cnts)}: {cnt}")
        
        cnt_data = df[df['CNT'] == cnt]
        
        index_cols = ['id', 'CNT', 'CNTSCHID', 'item', 'event_type']
        
        try:
            pivoted_chunk = cnt_data.pivot(
                index=['id', 'CNT', 'CNTSCHID', 'item'],
                columns='event_type',
                values='event_value'
            ).reset_index()
            
            pivoted_chunks.append(pivoted_chunk)
            
            del cnt_data
            del pivoted_chunk
            
        except Exception as e:
            print(f"Error processing {cnt}: {str(e)}")
            continue
    
    print("Combining final results...")
    df_wide = pd.concat(pivoted_chunks, ignore_index=True)
    
    print("Done!")
    return df_wide

# %%
df_math_p_final = process_and_pivot_by_cnt(df_math_p)
# df_read_p_final = process_and_pivot_by_cnt(df_read_p)
# df_sci_p_final = process_and_pivot_by_cnt(df_sci_p)
# Out:
# Processing 76 unique countries...
# Processing country 1 of 76: ALB
# Processing country 2 of 76: QAZ
# Processing country 3 of 76: ARG
# Processing country 4 of 76: AUS
# Processing country 5 of 76: AUT
# Processing country 6 of 76: BEL
# Processing country 7 of 76: BRA
# Processing country 8 of 76: BRN
# Processing country 9 of 76: BGR
# Processing country 10 of 76: CAN
# Processing country 11 of 76: CHL
# Processing country 12 of 76: TAP
# Processing country 13 of 76: COL
# Processing country 14 of 76: CRI
# Processing country 15 of 76: HRV
# Processing country 16 of 76: CZE
# Processing country 17 of 76: DNK
# Processing country 18 of 76: DOM
# Processing country 19 of 76: SLV
# Processing country 20 of 76: EST
# Processing country 21 of 76: FIN
# Processing country 22 of 76: FRA
# Processing country 23 of 76: GEO
# Processing country 24 of 76: PSE
# Processing country 25 of 76: DEU
# Processing country 26 of 76: GRC
# Processing country 27 of 76: HKG
# ...

# %%
# df_math_p_final
# df_read_p_final
# df_sci_p_final

# %%
df_math_p_final[['id', 'item']].value_counts()
# df_read_p_final[['id', 'item']].value_counts()
# df_sci_p_final[['id', 'item']].value_counts()
# Out:
# id          item
# 0.0         CMA127Q01    21
#             CMA127Q02    21
#             CMA127Q03    21
#             CMA157Q01    19
#             CMA151Q01    18
#                          ..
# 27600478.0  CMA108Q01     1
#             CMA108Q02     1
#             CMA108Q03     1
#             CMA136Q02     1
# 86007492.0  CMA157Q02     1
# Name: count, Length: 16002379, dtype: int64

# %%
df_math_final = df_math_ir.merge(df_math_p_final, 
    left_on=['id', 'CNTSCHID', 'item_join'],
    right_on=['id', 'CNTSCHID', 'item'],
    how='inner')

# df_read_final = df_read_ir.merge(df_read_p_final, 
#     left_on=['id', 'CNTSCHID', 'item_join'],
#     right_on=['id', 'CNTSCHID', 'item'],
#     how='inner')

# df_sci_final = df_sci_ir.merge(df_sci_p_final, 
#     left_on=['id', 'CNTSCHID', 'item_join'],
#     right_on=['id', 'CNTSCHID', 'item'],
#     how='inner')

# %%
# df_math_final
# df_read_final
# df_sci_final

# %%
df_math_final = df_math_final[['CNT_x', 'CNTSCHID', 'id', 'item_x', 'resp', 'num_actions', 'num_short_visits', 'num_visits', 'rt', 'time_to_first_action']]

df_math_final[['num_actions', 'num_short_visits', 'num_visits', 'rt', 'time_to_first_action']] = df_math_final[['num_actions', 'num_short_visits', 'num_visits', 'rt', 'time_to_first_action']].fillna(0)

df_math_final = df_math_final.rename(columns={
    'CNT_x': 'CNT',
    'item_x': 'item'
})

df_math_final[['CNTSCHID', 'id', 'resp', 'num_actions', 'num_short_visits', 'num_visits']] = df_math_final[['CNTSCHID', 'id', 'resp', 'num_actions', 'num_short_visits', 'num_visits']].apply(pd.to_numeric, errors='coerce').astype('Int64')

df_math_final[["rt", "time_to_first_action"]] = df_math_final[["rt", "time_to_first_action"]] / 1000



# df_read_final = df_read_final[['CNT_x', 'CNTSCHID', 'id', 'item_x', 'resp', 'num_actions', 'num_short_visits', 'num_visits', 'rt', 'time_to_first_action']]

# df_read_final[['num_actions', 'num_short_visits', 'num_visits', 'rt', 'time_to_first_action']] = df_read_final[['num_actions', 'num_short_visits', 'num_visits', 'rt', 'time_to_first_action']].fillna(0)

# df_read_final = df_read_final.rename(columns={
#     'CNT_x': 'CNT',
#     'item_x': 'item'
# })

# df_read_final[['CNTSCHID', 'id', 'resp', 'num_actions', 'num_short_visits', 'num_visits']] = df_read_final[['CNTSCHID', 'id', 'resp', 'num_actions', 'num_short_visits', 'num_visits']].apply(pd.to_numeric, errors='coerce').astype('Int64')

# df_read_final[["rt", "time_to_first_action"]] = df_read_final[["rt", "time_to_first_action"]] / 1000



# df_sci_final = df_sci_final[['CNT_x', 'CNTSCHID', 'id', 'item_x', 'resp', 'num_actions', 'num_short_visits', 'num_visits', 'rt', 'time_to_first_action']]

# df_sci_final[['num_actions', 'num_short_visits', 'num_visits', 'rt', 'time_to_first_action']] = df_sci_final[['num_actions', 'num_short_visits', 'num_visits', 'rt', 'time_to_first_action']].fillna(0)

# df_sci_final = df_sci_final.rename(columns={
#     'CNT_x': 'CNT',
#     'item_x': 'item'
# })

# df_sci_final[['CNTSCHID', 'id', 'resp', 'num_actions', 'num_short_visits', 'num_visits']] = df_sci_final[['CNTSCHID', 'id', 'resp', 'num_actions', 'num_short_visits', 'num_visits']].apply(pd.to_numeric, errors='coerce').astype('Int64')

# df_sci_final[["rt", "time_to_first_action"]] = df_sci_final[["rt", "time_to_first_action"]] / 1000

# %%
# df_math_final
# df_read_final
# df_sci_final

# %%
df_math_final.loc[(df_math_final['item'].str.startswith('D')) | (df_math_final['item'].isin(['CMA125Q01', 'CMA125Q02', 'CMA133Q02', 'CMA114Q04', 'CMA127Q01',
       'CMA152Q02', 'CMA103Q05', 'CMA124Q02', 'CMA101Q01', 'CMA117Q03',
       'CMA128Q02', 'CMA116Q02', 'CMA129Q02', 'CMA157Q01', 'CMA135Q03'])), 'resp'] = df_math_final['resp'].replace({1: 0, 2: 0, 11: 1, 12: 1, 13: 1, 14: 1, 21: 2, 22: 2, 23: 2})
# df_read_final.loc[(df_read_final['item'].str.startswith('D')) | (df_read_final['item'] == 'CR561Q06'), 'resp'] = df_read_final['resp'].replace({1: 0, 2: 0, 11: 1, 12: 1, 13: 1, 21: 2, 22: 2, 23: 2})
# df_sci_final.loc[df_sci_final['item'].str.startswith('D'), 'resp'] = df_sci_final['resp'].replace({1: 0, 2: 0, 11: 1, 12: 1, 13: 1, 21: 2, 22: 2, 23: 2})

# %%
# checker for encoding

# df_math_final["resp"].unique()
# df_math_final[df_math_final["resp"] == 11]["item"].unique()
# df_math_final
# Out:
#           CNT  CNTSCHID        id       item  resp  num_actions  \
# 0         ALB    800009    800028   CM033Q01     1           26
# 1         ALB    800161    800036   CM033Q01     1            2
# 2         ALB    800144    800042   CM033Q01     1            2
# 3         ALB    800286    800043   CM033Q01     0            2
# 4         ALB    800286    800045   CM033Q01     1           31
# ...       ...       ...       ...        ...   ...          ...
# 14708808  UZB  86000088  86007474  CMA135Q04     0            1
# 14708809  UZB  86000071  86007478  CMA135Q04     1            1
# 14708810  UZB  86000162  86007482  CMA135Q04     1            9
# 14708811  UZB  86000120  86007488  CMA135Q04     1            1
# 14708812  UZB  86000174  86007491  CMA135Q04     0            1
#
#           num_short_visits  num_visits       rt  time_to_first_action
# 0                        0           1   46.101                 5.260
# ...

# %%
df_math_final.to_csv('pisa2022_math.csv', index=False)
# df_read_final.to_csv('pisa2022_read.csv', index=False)
# df_sci_final.to_csv('pisa2022_science.csv', index=False)
